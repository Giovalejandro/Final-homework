# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * Create and save a project in Jupyter Notebook
# * Create Markdown cells and code in Jupyter Notebook
# * Study arithmetic expressions within the Python language

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Java
# 4. C++

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. Geopandas
# 4. Matplotlib
# 5. Seaborn
# 6. Scikit-Learn

# %% [markdown]
# | Data Science Tools |
# |----------|
# | Jupyter Notebook   |
# | Hadoop    |
# | Apache Spark  |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
#
# * Addition +
# * Subtraction -
# * Multiplication *
# * Division /
# * Modulus %
# * Exponent **
# * Quotient //

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
#  This will convert 200 minutes to hours by diving by 60
m = 200
h = m/60
print ( h,"hours")
# Out:
# 3.3333333333333335 hours

# %% [markdown]
# ## Author
# Jovanny Alejandro Herrera Mazabuel
